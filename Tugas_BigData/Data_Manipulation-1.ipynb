# %%
# Tugas 3
import pandas as pd
matrix = [[1,2,3],
          ['a','b','c'],
          [3,4,5],
          ['d',4,6]]

matrix_list = pd.DataFrame(matrix)

hasil = matrix_list.iloc[0:2, 2].to_list()
print(hasil)
# Out:
# [3, 'c']
